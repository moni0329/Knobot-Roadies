# %%
from google.colab import drive # Import the necessary module

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to YOLOv5 repository
repo_path = '/content/drive/MyDrive/yolov5'

# !pip install -r '/content/drive/MyDrive/yolov5/requirements.txt'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 37.2 MB/s eta 0:00:00
# ...

# %%
import sys
import os

# Get the absolute path of the YOLOv5 repository
repo_path = '/content/drive/MyDrive/yolov5'

# Add the YOLOv5 repository to the Python path
if repo_path not in sys.path:
    sys.path.insert(0, repo_path)

# Now import plot_results
from utils.plots import plot_results

# Rest of your code
plot_results("/content/drive/MyDrive/Models/BestmodelsTL/results.csv")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import torch

repo_path = '/content/drive/MyDrive/yolov5'
validation_path = '/content/drive/MyDrive/yolov5'
test_path = '/content/drive/MyDrive/yolov5'

# Path to the dataset
dataset_path = '/content/drive/MyDrive/DATASET/TL_Dataset'

# Path to the trained YOLOv5 model
model_path = '/content/drive/MyDrive/Models/BestmodelsTL/best.pt'

# Evaluate the model
# !python {validation_path}/val.py --data {dataset_path}/data.yaml --weights {model_path} --img 640 --batch 32 --iou 0.5 --task test
# Out:
# val: data=/content/drive/MyDrive/DATASET/TL_Dataset/data.yaml, weights=['/content/drive/MyDrive/Models/BestmodelsTL/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=drive/MyDrive/yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-385-gb968b2d7 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/yolov5/test/Images/labels... 93 images, 10 backgrounds, 0 corrupt: 100% 93/93 [00:44<00:00,  2.07it/s]
# test: New cache created: /content/drive/MyDrive/yolov5/test/Images/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [01:03<00:00, 21.18s/it]
# ...

# %%
precision = 0.855
recall = 0.884
mAP50 = 0.892

# Estimate accuracy
accuracy = (2 * precision * recall) / (precision + recall)
print(f"Approximate Accuracy: {accuracy * 100:.2f}%")
# Out:
# Approximate Accuracy: 86.93%
